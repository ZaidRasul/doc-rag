# %% [markdown]
# ## Data Ingestion

# %%
from langchain_core.document import Document
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain_core.document import Document
#
# ModuleNotFoundError: No module named 'langchain_core.document'

# %%
doc = Document(
    page_content="This is a test document.",
    metadata={"source": "test_source", "author": "test_author", "pages":1 },
)
doc
